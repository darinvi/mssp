# %%
import numpy as np

# %%
# Out:
# np.float64(7.38905609893065)

# %%
x = np.random.randn(100)
y = np.random.randn(100)

# %%
def lin(x, y):
    return

def lgn(x, y):
    return

def xpy(x, y):
    return

def pow(x, y):
    return

def rex(x, y):
    return

def rey(x, y):
    return

def sqr(x, y):
    return
    
def sin(x, y):
    return

def cos(x, y):
    return
# Out:
# array([-0.09229229,  0.22061124, -0.49322065, -1.16602516,  1.03987582,
#        -0.19806902, -0.40397845, -0.20060043, -0.04124321,  0.19089395,
#         0.92111932, -1.07121421,  0.52041987,  0.14471832,  1.01250241,
#        -0.46018888,  0.07597869, -0.21358554,  0.98220475,  0.52209183,
#        -0.19675933, -1.09391004, -0.94621239, -0.62216178, -0.61460839,
#         1.83368613,  1.12651146, -0.39249706, -0.15497847,  0.41863534,
#         0.26585247,  0.13444359,  0.37998795,  1.93213436,  1.34429528,
#        -0.94375401, -0.72592678,  2.50635928,  0.12676942,  2.40808311,
#        -0.24081976, -0.75882847, -1.1812512 ,  0.9644051 , -0.02169886,
#        -1.20599927,  1.01164268,  0.66834348,  0.27584783, -0.50477206,
#         0.68851666,  0.99200856, -0.07877025,  1.41718384, -0.24860981,
#         0.21120427, -1.56320703, -0.24033115,  0.59670511, -0.54585785,
#        -0.48551569, -1.1325995 , -2.22246372, -0.5037517 , -0.0483014 ,
# ...

# %%
# Out:
# array([-0.91309976, -0.65281017,  0.63661268, -1.03335721,  0.21359713,
#        -0.56122015,  1.38935301,  0.83755281,  1.07639032,  1.08143403,
#        -0.42446038,  0.49565985,  1.78564409,  0.21613061,  0.86854329,
#        -0.17577781,  1.32439379,  1.11110748,  1.38725656,  0.93463378,
#         0.11839935,  0.65712982,  1.30060204, -0.87821116,  1.21919362,
#        -0.21849809,  0.52061964,  0.32181322, -1.83669204,  1.64382618,
#        -1.76478266,  0.50071543, -1.13530935,  1.61587381, -0.68980411,
#        -1.02906385,  0.56197778,  0.22305693,  1.21696254,  0.67149021,
#        -0.23354794, -1.5688991 , -0.55574398,  0.74306413, -0.38123935,
#         1.66519607, -0.60367916,  1.24484469, -0.98835577, -0.59788603,
#         1.14955835,  1.52836654,  1.39610118, -0.83670367,  0.4770405 ,
#         0.42547449,  1.76830381, -0.66830571, -1.07179165,  0.30468279,
#        -0.18637845,  0.96189257, -1.49616094, -0.19899342,  0.12400007,
# ...
