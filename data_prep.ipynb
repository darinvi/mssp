# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('spy_raw.csv')[['adjClose']]
df['adjClose_log'] = np.log(df['adjClose'])
df['diff_log'] = df['adjClose_log'].diff()
df = df[['diff_log']]
for i in range(1,8):
    df[f'shift_{i}'] = df['diff_log'].shift(i)
for i in range(3, 9):
    df[f'rolling_{2**i}'] = df['diff_log'].rolling(2**i).mean()
df['target'] = df['diff_log'].shift(-1)
df.dropna(inplace=True)

# %%
df.plot(y='diff_log')
# Out:
# <Axes: >

# %%
df = df + df.min().abs() + 1e-6

# %%
df.to_csv("")
# Out:
#       diff_log   shift_1   shift_2   shift_3   shift_4   shift_5   shift_6  \
# 256   0.123598  0.082700  0.105065  0.162804  0.097618  0.096777  0.118930
# 257   0.113243  0.123598  0.082700  0.105065  0.162804  0.097618  0.096777
# 258   0.133305  0.113243  0.123598  0.082700  0.105065  0.162804  0.097618
# 259   0.116833  0.133305  0.113243  0.123598  0.082700  0.105065  0.162804
# 260   0.113995  0.116833  0.133305  0.113243  0.123598  0.082700  0.105065
# ...        ...       ...       ...       ...       ...       ...       ...
# 6533  0.120448  0.122098  0.124884  0.123411  0.104823  0.113151  0.114376
# 6534  0.119399  0.120448  0.122098  0.124884  0.123411  0.104823  0.113151
# 6535  0.115786  0.119399  0.120448  0.122098  0.124884  0.123411  0.104823
# 6536  0.112318  0.115786  0.119399  0.120448  0.122098  0.124884  0.123411
# 6537  0.114666  0.112318  0.115786  0.119399  0.120448  0.122098  0.124884
#
#        shift_7  rolling_8  rolling_16  rolling_32  rolling_64  rolling_128  \
# 256   0.123181   0.031760    0.018001    0.011431    0.006602     0.003978
# 257   0.118930   0.030518    0.018637    0.011189    0.006903     0.003833
# 258   0.096777   0.032315    0.021148    0.012489    0.007293     0.003982
# 259   0.097618   0.034822    0.020378    0.011886    0.007568     0.003973
# 260   0.162804   0.036869    0.021546    0.011553    0.007670     0.003907
# ...        ...        ...         ...         ...         ...          ...
# 6533  0.105077   0.033960    0.021484    0.013299    0.008767     0.005927
# 6534  0.114376   0.035750    0.021588    0.013378    0.008871     0.005869
# 6535  0.113151   0.035926    0.021366    0.012891    0.008942     0.005863
# 6536  0.104823   0.035822    0.021097    0.012708    0.008797     0.005775
# 6537  0.123411   0.037052    0.020902    0.012652    0.008734     0.005726
#
#       rolling_256    target
# 256      0.002204  0.113243
# 257      0.002350  0.133305
# 258      0.002411  0.116833
# 259      0.002478  0.113995
# 260      0.002250  0.122259
# ...           ...       ...
# 6533     0.003161  0.119399
# 6534     0.003158  0.115786
# 6535     0.003174  0.112318
# 6536     0.003278  0.114666
# 6537     0.003275  0.108451
#
# [6282 rows x 15 columns]
